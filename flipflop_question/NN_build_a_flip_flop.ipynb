# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# make some x data in range [-4,4], with values every 0.1
xData = np.arange( -4.0, 4.0, 0.1 )

# set up axes so that you can easily see the tanh curve
plt.axis( [ -4.0, 4.0, -1.1, 1.1 ] )

# plot lines
plt.plot( xData, np.tanh(xData), 'b', label='tanh')
plt.plot( xData, xData, 'r', label='y=x')
plt.plot( xData, xData/2, 'r--', label='y=x/2')

# put the legend in the lower-right
plt.legend(loc=4)

plt.show()
